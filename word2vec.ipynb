# %% [markdown]
# <a href="https://colab.research.google.com/github/TejaswiGithu/WORD2VEC/blob/main/word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from nltk.corpus import stopwords
import re

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/news.csv',error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 58426: expected 8 fields, saw 9\n'
# b'Skipping line 98836: expected 8 fields, saw 10\n'
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#               id                                              title  \
# 0            137  British coronavirus evacuee who was 'taken ill...
# 1            141  CDC files for emergency approval of its corona...
# 2            142  Can ANY face mask really protect you from the ...
# 3            144  Experts: You won't catch coronavirus from pack...
# 4            147  Seventh American diagnosed with coronavirus as...
# ...          ...                                                ...
# 161626  39845797  Why have deaths stayed steady while infections...
# 161627  39846088  Trump says three novel coronavirus vaccine can...
# 161628  39847130  Coronavirus: Trump touts response as COVID-19 ...
# 161629  39847587  Woman, 21, 'attacked five airline ticketing ag...
# 161630  39847765  Why Morehouse and Clemson Made Different Footb...
#
#                                               description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 161626  Covid-19 cases have recently spiked across the...
# 161627  WASHINGTON — U.S. President Donald Trump on Th...
# 161628                                                NaN
# 161629  Emmari Jackson was arrested and taken into cus...
# 161630  Morehouse, the first scholarship football prog...
#
#                                                      link            source  \
# 0       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# 1       https://www.dailymail.co.uk/health/article-796...   dailymail.co.uk
# 2       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# 3       https://www.dailymail.co.uk/health/article-796...   dailymail.co.uk
# 4       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# ...                                                   ...               ...
# 161626  https://www.cnn.com/2020/07/02/opinions/steady...       rss.cnn.com
# 161627  https://nationalpost.com/pmn/health-pmn/trump-...  nationalpost.com
# 161628  https://www.usatoday.com/story/news/politics/2...      usatoday.com
# 161629  https://www.dailymail.co.uk/news/article-84840...   dailymail.co.uk
# 161630  https://www.nytimes.com/2020/07/01/sports/ncaa...   rss.nytimes.com
#
#                         source_link              crawled       published_date
# 0       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-04 08:09:54
# 1       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 21:25:50
# 2       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 21:19:39
# 3       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 19:35:43
# 4       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-01 02:30:11
# ...                             ...                  ...                  ...
# 161626     https://edition.cnn.com/  2020-07-02 16:25:11  2020-07-02 16:09:57
# 161627     https://nationalpost.com  2020-07-02 16:25:24  2020-07-02 16:22:27
# 161628    https://www.usatoday.com/  2020-07-02 16:30:36  2020-07-02 16:26:10
# 161629  https://www.dailymail.co.uk  2020-07-02 16:35:12  2020-07-02 16:34:02
# 161630      https://rss.nytimes.com  2020-07-02 16:35:24  2020-07-02 11:35:42
#
# [161631 rows x 8 columns]

# %%
def preprocess(text):
    text_input = re.sub('[^a-zA-Z1-9]+', ' ', str(text))
    output = re.sub(r'\d+', '',text_input)
    return output.lower().strip()

data['title'] = data.title.map(preprocess)
data
# Out:
#               id                                              title  \
# 0            137  british coronavirus evacuee who was taken ill ...
# 1            141  cdc files for emergency approval of its corona...
# 2            142  can any face mask really protect you from the ...
# 3            144  experts you won t catch coronavirus from packa...
# 4            147  seventh american diagnosed with coronavirus as...
# ...          ...                                                ...
# 161626  39845797  why have deaths stayed steady while infections...
# 161627  39846088  trump says three novel coronavirus vaccine can...
# 161628  39847130  coronavirus trump touts response as covid  dai...
# 161629  39847587  woman  attacked five airline ticketing agents ...
# 161630  39847765  why morehouse and clemson made different footb...
#
#                                               description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 161626  Covid-19 cases have recently spiked across the...
# 161627  WASHINGTON — U.S. President Donald Trump on Th...
# 161628                                                NaN
# 161629  Emmari Jackson was arrested and taken into cus...
# 161630  Morehouse, the first scholarship football prog...
#
#                                                      link            source  \
# 0       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# 1       https://www.dailymail.co.uk/health/article-796...   dailymail.co.uk
# 2       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# 3       https://www.dailymail.co.uk/health/article-796...   dailymail.co.uk
# 4       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# ...                                                   ...               ...
# 161626  https://www.cnn.com/2020/07/02/opinions/steady...       rss.cnn.com
# 161627  https://nationalpost.com/pmn/health-pmn/trump-...  nationalpost.com
# 161628  https://www.usatoday.com/story/news/politics/2...      usatoday.com
# 161629  https://www.dailymail.co.uk/news/article-84840...   dailymail.co.uk
# 161630  https://www.nytimes.com/2020/07/01/sports/ncaa...   rss.nytimes.com
#
#                         source_link              crawled       published_date
# 0       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-04 08:09:54
# 1       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 21:25:50
# 2       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 21:19:39
# 3       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 19:35:43
# 4       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-01 02:30:11
# ...                             ...                  ...                  ...
# 161626     https://edition.cnn.com/  2020-07-02 16:25:11  2020-07-02 16:09:57
# 161627     https://nationalpost.com  2020-07-02 16:25:24  2020-07-02 16:22:27
# 161628    https://www.usatoday.com/  2020-07-02 16:30:36  2020-07-02 16:26:10
# 161629  https://www.dailymail.co.uk  2020-07-02 16:35:12  2020-07-02 16:34:02
# 161630      https://rss.nytimes.com  2020-07-02 16:35:24  2020-07-02 11:35:42
#
# [161631 rows x 8 columns]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop = set(stopwords.words("english"))

def remove_stopwords(text):
    filtered_words = [word.lower() for word in text.split() if word.lower() not in stop]
    return " ".join(filtered_words)

data['title'] = data.title.map(remove_stopwords)
data
# Out:
#               id                                              title  \
# 0            137  british coronavirus evacuee taken ill last fli...
# 1            141      cdc files emergency approval coronavirus test
# 2            142               face mask really protect coronavirus
# 3            144           experts catch coronavirus packages china
# 4            147  seventh american diagnosed coronavirus us decl...
# ...          ...                                                ...
# 161626  39845797            deaths stayed steady infections spiking
# 161627  39846088  trump says three novel coronavirus vaccine can...
# 161628  39847130  coronavirus trump touts response covid daily c...
# 161629  39847587  woman attacked five airline ticketing agents c...
# 161630  39847765  morehouse clemson made different football choices
#
#                                               description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 161626  Covid-19 cases have recently spiked across the...
# 161627  WASHINGTON — U.S. President Donald Trump on Th...
# 161628                                                NaN
# 161629  Emmari Jackson was arrested and taken into cus...
# 161630  Morehouse, the first scholarship football prog...
#
#                                                      link            source  \
# 0       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# 1       https://www.dailymail.co.uk/health/article-796...   dailymail.co.uk
# 2       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# 3       https://www.dailymail.co.uk/health/article-796...   dailymail.co.uk
# 4       https://www.dailymail.co.uk/health/article-795...   dailymail.co.uk
# ...                                                   ...               ...
# 161626  https://www.cnn.com/2020/07/02/opinions/steady...       rss.cnn.com
# 161627  https://nationalpost.com/pmn/health-pmn/trump-...  nationalpost.com
# 161628  https://www.usatoday.com/story/news/politics/2...      usatoday.com
# 161629  https://www.dailymail.co.uk/news/article-84840...   dailymail.co.uk
# 161630  https://www.nytimes.com/2020/07/01/sports/ncaa...   rss.nytimes.com
#
#                         source_link              crawled       published_date
# 0       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-04 08:09:54
# 1       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 21:25:50
# 2       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 21:19:39
# 3       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-03 19:35:43
# 4       https://www.dailymail.co.uk  2020-02-04 08:31:29  2020-02-01 02:30:11
# ...                             ...                  ...                  ...
# 161626     https://edition.cnn.com/  2020-07-02 16:25:11  2020-07-02 16:09:57
# 161627     https://nationalpost.com  2020-07-02 16:25:24  2020-07-02 16:22:27
# 161628    https://www.usatoday.com/  2020-07-02 16:30:36  2020-07-02 16:26:10
# 161629  https://www.dailymail.co.uk  2020-07-02 16:35:12  2020-07-02 16:34:02
# 161630      https://rss.nytimes.com  2020-07-02 16:35:24  2020-07-02 11:35:42
#
# [161631 rows x 8 columns]

# %%
def build_corpus(data):
    corpus = []
    for sentence in data.iteritems():
        word_list = sentence[1].split(" ")
        corpus.append(word_list)
    return corpus

corpus = build_corpus(data['title'])

# %%
model = Word2Vec(corpus, size=100, min_count=1)

# %%
# fit a 2D PCA model to the vectors
vectors = model[model.wv.vocab]
words = list(model.wv.vocab)
pca = PCA(n_components=2)
PCA_result = pca.fit_transform(vectors)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
# prepare a dataframe
words = pd.DataFrame(words)
PCA_result = pd.DataFrame(PCA_result)
PCA_result['x_values'] =PCA_result.iloc[0:, 0]
PCA_result['y_values'] =PCA_result.iloc[0:, 1]
PCA_final = pd.merge(words, PCA_result, left_index=True, right_index=True)
PCA_final['word'] =PCA_final.iloc[0:, 0]
PCA_data_complet =PCA_final[['word','x_values','y_values']]
PCA_data_complet.to_csv('PCA_data_complet.csv',index=False)

# %%
print(PCA_data_complet)
# Out:
#               word  x_values  y_values
# 0          british  2.617919  1.764845
# 1      coronavirus  2.086818 -0.834924
# 2          evacuee  0.471092  0.309744
# 3            taken  1.996022  1.184495
# 4              ill  2.325356  2.273200
# ...            ...       ...       ...
# 35170    masterjee -0.519539 -0.053149
# 35171     netizens -0.515715 -0.049644
# 35172     untraced -0.566254 -0.069612
# 35173      furough -0.563329 -0.079036
# 35174  explosively -0.523365 -0.098355
#
# [35175 rows x 3 columns]

# %%
# word frequencies calculation
from collections import Counter
# count unique words
def counter_word(text_col):
    count = Counter()
    for text in text_col.values:
        for word in text.split():
            count[word] += 1
    return count

counter_all = counter_word(data.title)
words_all = counter_all.most_common(100)

words_all= pd.DataFrame(words_all)
words_all['word'] = words_all.iloc[0:, 0]
words_all['count'] = words_all.iloc[0:, 1]
words_all = words_all[['word','count']]
words_all.to_csv('top100_words.csv', columns=['word','count'], index=False)

# %%
# restriction to 100 most frequent words
top100_words = pd.read_csv('top100_words.csv')
PCA_data_top_100 = PCA_data_complet.merge(top100_words, how='inner', left_on='word',right_on='word')
PCA_data_top_100.to_csv('PCA_data_top_100.csv', index=False)
